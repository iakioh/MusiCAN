# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Create local clone of GitHub repository (only once)
'''
git_token = "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"
# %cd /content/drive/MyDrive/Uni/
# !git clone https://{git_token}@github.com/iakioh/MusiCAN.git
''';

# %%
# Before any git actions, run this cell

repo_path = "/content/drive/MyDrive/Uni/MusiCAN"
git_token = "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"

# %cd {repo_path}
# !git pull origin main
# !git status
# Out:
# /content/drive/MyDrive/Uni/MusiCAN
# From https://github.com/iakioh/MusiCAN
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
